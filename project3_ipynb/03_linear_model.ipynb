# %%
################### #
# Attach packages ----
################### #

library(tidyverse)
library(tidymodels)
library(readxl)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.2 ──
#
# ✔ broom     0.7.5      ✔ recipes   0.1.15
# ✔ dials     0.0.9      ✔ rsample   0.0.9
# ✔ infer     0.5.4      ✔ tune      0.1.3
# ✔ modeldata 0.1.0      ✔ workflows 0.2.2
# ✔ parsnip   0.1.5      ✔ yardstick 0.0.8
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()

# %%
#################### #
# Import data ----
#################### #

houses_raw <- read_excel("temp/houses.xlsx")

# %%
head(houses_raw,3)
# Out:
#   id    sqm price   debt   expense lat      lng      kommune_no kommune_name
# 1 10001 152 9800000      0    0    59.95475 10.76841 0301       Oslo
# 2 10002  66 3100000 175086 5147    59.94381 10.81159 0301       Oslo
# 3 10003 189 8400000      0    0    59.98290 11.01450 0231       Skedsmo
#   fylke_no ⋯ zip_no zip_name avg_income avg_fortune sqm_use built floor
# 1 0300     ⋯ 0484   Oslo     428890     755524      190     1959  1
# 2 0300     ⋯ 0590   Oslo     421739     867066       66     1954  2
# 3 0200     ⋯ 2007   Kjeller  356058     645496      234     1987  3
#   tot_price tot_price_per_sqm n_houses_nearby
# 1 9800000   64473.68          110
# 2 3275086   49622.52          101
# 3 8400000   44444.44           24

# %%
distinct_df = houses %>% distinct(kommune_name)
length(distinct_df$kommune_name)
# Out:
# [1] 226

# %%
#################### #
# Transform data ----
#################### #

houses <- houses_raw %>%
  select(sqm, expense, tot_price, lat, lng, kommune_name) %>%
  mutate(kommune_name = fct_lump_n(kommune_name, 220),
         log_sqm      = log(sqm))

# %%
head(houses,3)
# Out:
#   sqm expense tot_price lat      lng      kommune_name log_sqm
# 1 152    0    9800000   59.95475 10.76841 Oslo         5.023881
# 2  66 5147    3275086   59.94381 10.81159 Oslo         4.189655
# 3 189    0    8400000   59.98290 11.01450 Skedsmo      5.241747

# %%
distinct_df = houses %>% distinct(kommune_name)
distinct_df$kommune_name
# Out:
#   [1] Oslo               Skedsmo            Oppegård
#   [4] Bærum              Kristiansund       Haugesund
#   [7] Trondheim          Stavanger          Other
#  [10] Melhus             Rælingen           Moss
#  [13] Sande              Drammen            Sandefjord
#  [16] Røyken             Asker              Bergen
#  [19] Åsnes              Enebakk            Sørum
#  [22] Lørenskog          Molde              Vestby
#  [25] Re                 Bømlo              Bodø
#  [28] Randaberg          Ski                Fredrikstad
#  [31] Nittedal           Hammerfest         Lindås
#  [34] Harstad - Hárstták Sola               Sogndal
#  [37] Målselv            Karmøy             Skodje
#  [40] Arendal            Tromsø             Rygge
#  [43] Frogn              Hamar              Nes
#  [46] Fjell              Ullensaker         Ås
#  [49] Horten             Tønsberg           Gran
#  [52] Sandnes            Eidsvoll           Porsgrunn
#  [55] Hobøl              Nannestad          Ørsta
#  [58] Aurskog-Høland     Nesodden           Gjerdrum
#  [61] Stange             Larvik             Gjøvik
#  [64] Froland            Øygarden           Ringerike
#  [67] Stord              Sarpsborg          Frøya
#  [70] Gjesdal            Lier               Fet
#  [73] Trøgstad           Skien              Øvre Eiker
#  [76] Ålesund            Kongsvinger        Kristiansand
#  [79] Notodden           Lillehammer        Askøy
#  [82] Time               Midtre Gauldal     Kragerø
#  [85] Herøy              Ulstein            Indre Fosen
#  [88] Klepp              Narvik             Os
#  [91] Østre Toten        Bamble             Bjerkreim
#  [94] Vefsn              Søgne              Elverum
#  [97] Kvinnherad         Brønnøy            Averøy
# [100] Ringsaker          Verdal             Hå
# [103] Lillesand          Gol                Namsos
# [106] Stjørdal           Songdalen          Skaun
# [109] Levanger           Etne               Halden
# [112] Ørland             Hadsel             Lenvik
# [115] Grimstad           Alstahaug          Birkenes
# [118] Flora              Førde              Finnøy
# [121] Mandal             Askim              Spydeberg
# [124] Holmestrand        Eigersund          Lunner
# [127] Sula               Gausdal            Haram
# [130] Strand             Nedre Eiker        Malvik
# [133] Orkdal             Kongsberg          Meldal
# [136] Meland             Lindesnes          Alta
# [139] Flekkefjord        Våler              Nesna
# [142] Lund               Årdal              Rakkestad
# [145] Tysvær             Vadsø              Jevnaker
# [148] Aukra              Stranda            Radøy
# [151] Selbu              Bardu              Bjugn
# [154] Vågan              Åmot               Vennesla
# [157] Sveio              Sør-Varanger       Tynset
# [160] Risør              Rana               Øksnes
# [163] Vindafjord         Sund               Rauma
# [166] Sunndal            Modum              Sokndal
# [169] Odda               Nordreisa          Oppdal
# [172] Hurum              Røros              Sør-Odal
# [175] Ål                 Nome               Sykkylven
# [178] Søndre Land        Steinkjer          Vestre Toten
# [181] Færder             Rennesøy           Farsund
# [184] Voss               Vestnes            Volda
# [187] Inderøy            Fræna              Hjelmeland
# [190] Sauda              Bø                 Evje og Hornnes
# [193] Tvedestrand        Iveland            Tinn
# [196] Klæbu              Hitra              Fauske - Fuosko
# [199] Meløy              Surnadal           Nordre Land
# [202] Hareid             Giske              Sel
# [205] Hvaler             Andøy              Fusa
# [208] Leirfjord          Lyngdal            Vågsøy
# [211] Saltdal            Smøla              Deatnu - Tana
# [214] Balsfjord          Austevoll          Sortland - Suortá
# [217] Dønna              Verran             Kvam
# [220] Drangedal          Suldal             Kvinesdal
# [223] Osterøy            Eide               Lødingen
# [226] Stor-Elvdal
# 226 Levels: Alstahaug Alta Andøy Arendal Asker Askim Askøy ... Other

# %%
#################### #
# Split data ----
#################### #

set.seed(42)

split <- initial_split(houses, prop = 3/4)
train <- training(split)
test  <- testing(split)

# %%
#################### #
# Fit a linear model  ----
#################### #

linear_model <- linear_reg() %>% 
  set_engine("lm") %>% 
  fit(log(tot_price) ~ ., data = train)

# View summary of fit
summary(linear_model$fit)
# Out:
# Call:
# stats::lm(formula = log(tot_price) ~ ., data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.67753 -0.17794  0.00152  0.17895  1.71367
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     1.422e+01  3.449e-01  41.243  < 2e-16 ***
# sqm                            -5.069e-04  3.521e-05 -14.399  < 2e-16 ***
# expense                         6.822e-06  1.375e-06   4.962 7.07e-07 ***
# lat                            -4.507e-02  5.808e-03  -7.761 9.00e-15 ***
# lng                             5.201e-03  4.296e-03   1.211 0.226043
# kommune_nameAlta                5.320e-01  8.108e-02   6.561 5.51e-11 ***
# kommune_nameAndøy              -6.062e-01  1.009e-01  -6.009 1.91e-09 ***
# kommune_nameArendal            -2.891e-01  6.598e-02  -4.381 1.19e-05 ***
# kommune_nameAsker               6.680e-01  6.853e-02   9.748  < 2e-16 ***
# kommune_nameStjørdal            3.770e-01  6.697e-02   5.630 1.83e-08 ***
# kommune_nameStor-Elvdal        -1.135e+00  1.236e-01  -9.177  < 2e-16 ***
# kommune_nameStord              -2.276e-01  6.586e-02  -3.456 0.000549 ***
# kommune_nameStrand              3.826e-03  6.719e-02   0.057 0.954592
# kommune_nameStranda            -7.622e-01  1.227e-01  -6.213 5.35e-10 ***
# kommune_nameSula                1.843e-01  9.071e-02   2.032 0.042213 *
# kommune_nameSuldal             -4.243e-01  1.079e-01  -3.934 8.40e-05 ***
# kommune_nameSund               -1.785e-01  9.014e-02  -1.980 0.047753 *
# kommune_nameSunndal            -6.195e-01  9.302e-02  -6.659 2.85e-11 ***
# kommune_nameSurnadal           -3.196e-01  1.224e-01  -2.612 0.009010 **
# kommune_nameSveio              -2.654e-01  7.874e-02  -3.371 0.000752 ***
# kommune_nameSykkylven          -1.219e-01  1.013e-01  -1.203 0.228848
# kommune_nameSøgne              -9.190e-02  7.398e-02  -1.242 0.214190
# kommune_nameSøndre Land        -8.382e-01  9.877e-02  -8.487  < 2e-16 ***
# kommune_nameSør-Odal           -2.190e-01  1.167e-01  -1.877 0.060568 .
# kommune_nameSør-Varanger       -8.289e-02  9.655e-02  -0.859 0.390594
# kommune_nameSørum               3.674e-01  7.846e-02   4.683 2.86e-06 ***
# kommune_nameTime                5.982e-02  6.505e-02   0.920 0.357804
# kommune_nameTinn               -1.230e+00  9.240e-02 -13.311  < 2e-16 ***
# kommune_nameTromsø              8.409e-01  6.009e-02  13.995  < 2e-16 ***
# kommune_nameTrondheim           5.432e-01  5.555e-02   9.779  < 2e-16 ***
# kommune_nameTrøgstad           -2.621e-01  1.320e-01  -1.986 0.047089 *
# kommune_nameTvedestrand        -3.970e-01  9.123e-02  -4.352 1.36e-05 ***
# kommune_nameTynset             -2.323e-01  1.100e-01  -2.112 0.034734 *
# kommune_nameTysvær             -1.756e-01  7.520e-02  -2.336 0.019525 *
# kommune_nameTønsberg            2.206e-01  6.771e-02   3.259 0.001121 **
# kommune_nameUllensaker          3.938e-01  6.725e-02   5.856 4.84e-09 ***
# kommune_nameUlstein            -1.565e-03  8.195e-02  -0.019 0.984765
# kommune_nameVadsø              -3.847e-01  9.760e-02  -3.942 8.13e-05 ***
# kommune_nameVefsn               9.494e-02  8.287e-02   1.146 0.251925
# kommune_nameVennesla           -3.356e-01  7.153e-02  -4.691 2.74e-06 ***
# kommune_nameVerdal             -5.553e-02  7.385e-02  -0.752 0.452160
# kommune_nameVerran             -1.037e+00  1.128e-01  -9.187  < 2e-16 ***
# kommune_nameVestby              3.420e-01  8.030e-02   4.259 2.07e-05 ***
# kommune_nameVestnes            -3.379e-01  9.336e-02  -3.619 0.000296 ***
# kommune_nameVestre Toten       -1.321e-01  1.010e-01  -1.308 0.190842
# kommune_nameVindafjord         -3.844e-01  7.982e-02  -4.815 1.48e-06 ***
# kommune_nameVolda              -7.840e-02  9.371e-02  -0.837 0.402823
# kommune_nameVoss               -6.114e-02  1.042e-01  -0.587 0.557542
# kommune_nameVågan               1.455e-01  1.031e-01   1.410 0.158474
# kommune_nameVågsøy             -5.162e-01  8.764e-02  -5.890 3.95e-09 ***
# kommune_nameVåler              -2.416e-01  9.447e-02  -2.558 0.010542 *
# kommune_nameÅl                 -3.175e-01  1.074e-01  -2.955 0.003132 **
# kommune_nameÅlesund             1.361e-01  6.069e-02   2.243 0.024932 *
# kommune_nameÅmot               -7.315e-01  1.084e-01  -6.748 1.56e-11 ***
# kommune_nameÅrdal              -5.663e-01  7.749e-02  -7.308 2.86e-13 ***
# kommune_nameÅs                  4.601e-01  8.010e-02   5.744 9.42e-09 ***
# kommune_nameÅsnes              -7.492e-01  9.418e-02  -7.955 1.92e-15 ***
# kommune_nameØksnes             -5.198e-01  8.869e-02  -5.861 4.70e-09 ***
# kommune_nameØrland              7.841e-03  8.406e-02   0.093 0.925684
# kommune_nameØrsta               3.485e-02  8.713e-02   0.400 0.689230
# kommune_nameØstre Toten        -2.428e-01  8.652e-02  -2.806 0.005019 **
# kommune_nameØvre Eiker          1.356e-01  8.350e-02   1.624 0.104487
# kommune_nameØygarden           -1.676e-01  1.105e-01  -1.516 0.129457
# kommune_nameOther              -4.917e-01  5.600e-02  -8.780  < 2e-16 ***
# log_sqm                         7.220e-01  7.163e-03 100.795  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3288 on 14925 degrees of freedom
# Multiple R-squared:  0.6688,	Adjusted R-squared:  0.6637
# F-statistic: 131.1 on 230 and 14925 DF,  p-value: < 2.2e-16

# %%
#################### #
# Use model for predictions  ----
#################### #

linear_model_preds <- 
  predict(linear_model, test) %>% 
  bind_cols(test) %>% 
  mutate(.pred = exp(.pred)) %>% 
  rename(estimate     = .pred, 
         truth        = tot_price) %>% 
  mutate(abs_dev      = abs(truth - estimate),
         abs_dev_perc = abs_dev/truth) %>% 
  select(estimate, truth, everything()) # See comment below

# `select(estimate, truth, everything())` is a trick to reorder the columns such that `estimate` and `truth` appears
# as the first two columns in the dataset. This was not requested of the students in the exercise.

# %%
head(linear_model_preds,3)
# Out:
#   estimate truth   sqm expense lat      lng      kommune_name log_sqm
# 1 4704616  3275086  66 5147    59.94381 10.81159 Oslo         4.189655
# 2 2868415  3035761  33 3559    59.94471 10.77751 Oslo         3.496508
# 3 3674076  2350000 244    0    63.10960  7.72550 Kristiansund 5.497168
#   abs_dev   abs_dev_perc
# 1 1429530.4 0.4364864
# 2  167345.7 0.0551248
# 3 1324076.1 0.5634366

# %%
#################### #
# Evaluate model  ----
#################### #

mape(data = linear_model_preds, truth = truth, estimate = estimate)
# Out:
#   .metric .estimator .estimate
# 1 mape    standard   27.13198

# %%
linear_model_preds %>% 
  ggplot(aes(x = estimate/1000000, y = truth/1000000)) +
  geom_point(color = "dodgerblue3", alpha = 0.4) +
  labs(x = "Predikert pris [MNOK]",
       y = "Faktisk pris [MNOK]") +
  theme_minimal()
# Out:
# plot without title

# %%
##################################### #
# Plot results ----
##################################### #

linear_model_preds %>%
  ggplot(aes(x = abs_dev_perc)) +
  geom_histogram(fill = "dodgerblue3", color = "white", bins=50) +
  labs(x = "Prosentvis feil",
       y = "Antall observasjoner") +
  scale_x_continuous(limits = c(0,5), labels = scales::percent) +   
  theme_minimal()
# Out:
# Warning message:
# “Removed 4 rows containing non-finite values (stat_bin).”
# Warning message:
# “Removed 2 rows containing missing values (geom_bar).”
# plot without title
